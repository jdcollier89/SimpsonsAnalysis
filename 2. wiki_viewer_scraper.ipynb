# %% [markdown]
# This notebook pulls data from wikipedia, which includes the number of viewers each episode had on its original airing (within the US).

# %%
# First 20 seasons
# https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)

# Seasons 21 - current
# https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes

from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# # Define Functions

# %%
def scrape_ep_tables(ep_url):
    """Get episode tables (for each season) from wikipedia"""
    
    # Request from the server the content of the web page by using get()
    response = get(ep_url)

    # Parse the content of the request with BeautifulSoup
    page_html = BeautifulSoup(response.text, 'html.parser')

    # Extract each season table into ep_tables. Each index is a seperate season
    ep_tables = page_html.find_all('table', class_='wikiepisodetable')
    
    return ep_tables

# %%
def extract_ep_details(rows):
    """Extract Details of Episodes"""
    
    season_list = []
    for row in rows:
        overall_ep = row.find('th')
        try:
            overall_ep = overall_ep.text.strip()
        except:
            continue;
        cols=row.find_all('td')
        cols=[x.text.strip() for x in cols]
        cols.append(overall_ep) # Append the overall episode number
        cols.append(season) # Append Season No
        season_list.append(cols)
    del season_list[0] # Delete header
    simpsons_episodes = pd.DataFrame(season_list, columns=['episode', 'ep_title', 'director', 'writer', 
                                                   'air_date', 'prod_code', 'viewers', 'ep_overall', 'season'])  
    return simpsons_episodes

# %%
def identify_exceptions(rows):
    """Identify tables which have been found but do not represent a season of episodes (e.g. movie)"""
    skip_flag = False
    
    headers = rows[0].find_all('th')
    for header in headers:
        header = header.text.strip()
        if header == 'Screenplay by':
            skip_flag = True
        if 'Household' in header:
            skip_flag = True    
            
    return skip_flag

# %%
def remove_reference_tags(ep_list):
    """Use regular expressions to identify reference tags and remove them"""
    pattern = r'\[[^\]]*\]'

    ep_list['viewers'] = ep_list['viewers'].apply(lambda x: re.sub(pattern, '', x))
    return ep_list

# %% [markdown]
# # Build Dataset

# %%
url1 = 'https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)'
url2 = 'https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes'

ep_tables1 = scrape_ep_tables(url1)
ep_tables2 = scrape_ep_tables(url2)

ep_tables = ep_tables1 + ep_tables2

# %%
ep_list = pd.DataFrame(columns=['episode', 'ep_title', 'director', 'writer', 
                                'air_date', 'prod_code', 'viewers', 'ep_overall', 'season'])
season = 1
max_season = 31

for i in range(len(ep_tables)):
    if season >= max_season+1:
        continue
        
    season_table = ep_tables[i]
    season_rows = season_table.find_all('tr')
            
    if identify_exceptions(season_rows): # Skip table if not a season of episodes
        continue
        
    simpsons_episodes = extract_ep_details(season_rows)
    ep_list = ep_list.append(simpsons_episodes)
    season += 1 # Increment season if table not skipped

# %%
ep_list = remove_reference_tags(ep_list)

# %%
ep_list
# Out:
#    episode                                           ep_title  \
# 0        1                "Simpsons Roasting on an Open Fire"
# 1        2                                  "Bart the Genius"
# 2        3                                  "Homer's Odyssey"
# 3        4                    "There's No Disgrace Like Home"
# 4        5                                 "Bart the General"
# 5        6                                     "Moaning Lisa"
# 6        7                         "The Call of the Simpsons"
# 7        8                                "The Telltale Head"
# 8        9                            "Life on the Fast Lane"
# 9       10                                "Homer's Night Out"
# 10      11                              "The Crepes of Wrath"
# 11      12                               "Krusty Gets Busted"
# 12      13                           "Some Enchanted Evening"
# 0        1                                 "Bart Gets an "F""
# 1        2                              "Simpson and Delilah"
# 2        3                              "Treehouse of Horror"
# 3        4  "Two Cars in Every Garage and Three Eyes on Ev...
# 4        5                                    "Dancin' Homer"
# 5        6                             "Dead Putting Society"
# 6        7                            "Bart vs. Thanksgiving"
# 7        8                               "Bart the Daredevil"
# 8        9                         "Itchy & Scratchy & Marge"
# 9       10                           "Bart Gets Hit by a Car"
# 10      11          "One Fish, Two Fish, Blowfish, Blue Fish"
# 11      12                                   "The Way We Was"
# 12      13           "Homer vs. Lisa and the 8th Commandment"
# 13      14                               "Principal Charming"
# 14      15                      "Oh Brother, Where Art Thou?"
# 15      16                           "Bart's Dog Gets an "F""
# 16      17                                        "Old Money"
# ..     ...                                                ...
# 15      16                      "I Want You (She's So Heavy)"
# 16      17                                      "E My Sports"
# 17      18                        "Bart vs. Itchy & Scratchy"
# 18      19                               "Girl's in the Band"
# 19      20               "I'm Just a Girl Who Can't Say D'oh"
# 20      21                                      "D'oh Canada"
# 21      22                                  "Woo-Hoo Dunnit?"
# 22      23                   "Crystal Blue-Haired Persuasion"
# 0        1              "The Winter of Our Monetized Content"
# 1        2                               "Go Big or Go Homer"
# 2        3                                "The Fat Blue Line"
# 3        4                          "Treehouse of Horror XXX"
# 4        5                             "Gorillas on the Mast"
# 5        6                             "Marge the Lumberjill"
# 6        7                               "Livin La Pura Vida"
# 7        8                           "Thanksgiving of Horror"
# 8        9           "Todd, Todd, Why Hast Thou Forsaken Me?"
# 9       10                         "Bobby, It's Cold Outside"
# 10      11                                "Hail to the Teeth"
# 11      12                 "The Miseducation of Lisa Simpson"
# 12      13                                        "Frinkcoin"
# 13      14                                 "Bart the Bad Guy"
# 14      15                                       "Screenless"
# 15      16                                   "Better Off Ned"
# 16      17                                  "Highway to Well"
# 17      18         "The Incredible Lightness of Being a Baby"
# 18      19                       "Warrin' Priests (Part One)"
# 19      20                       "Warrin' Priests (Part Two)"
# 20      21                      "The Hateful Eight-Year-Olds"
# 21      22                               "The Way of the Dog"
#
#                               director  \
# 0                      David Silverman
# 1                      David Silverman
# 2                        Wesley Archer
# 3       Gregg Vanzo & Kent Butterworth
# 4                      David Silverman
# 5                        Wesley Archer
# 6                        Wesley Archer
# 7                           Rich Moore
# 8                      David Silverman
# 9                           Rich Moore
# 10         Wesley Archer & Milton Gray
# 11                           Brad Bird
# 12  David Silverman & Kent Butterworth
# 0                      David Silverman
# 1                           Rich Moore
# 2                           Wes Archer
# 3                           Wes Archer
# 4                        Mark Kirkland
# 5                           Rich Moore
# 6                      David Silverman
# 7                  Wesley Meyer Archer
# 8                          Jim Reardon
# 9                        Mark Kirkland
# 10                    Wesley M. Archer
# 11                     David Silverman
# 12                          Rich Moore
# 13                       Mark Kirkland
# 14                   W.M. "Bud" Archer
# 15                         Jim Reardon
# 16                     David Silverman
# ..                                 ...
# 15                   Steven Dean Moore
# 16                          Rob Oliver
# 17                      Chris Clements
# 18                    Jennifer Moeller
# 19                     Michael Polcino
# 20                      Matthew Nastuk
# 21                   Steven Dean Moore
# 22                    Matthew Faughnan
# 0                         Bob Anderson
# 1                     Matthew Faughnan
# 2                      Michael Polcino
# 3                       Timothy Bailey
# 4                       Matthew Nastuk
# 5                           Rob Oliver
# 6                       Timothy Bailey
# 7                           Rob Oliver
# 8                       Chris Clements
