# %% [markdown]
# The notebook loops through each season of the Simpsons on IMDb and pulls the basic information provided.
#
# As I want to keep the number of hits on IMDb to a reasonable amount, the loop only pulls data from the season tables, and does not drill down into each episode (despite that offering more data).

# %%
# Simpsons IMDb link
# https://www.imdb.com/title/tt0096697/episodes?season=1

from requests import get
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# The fields found on the webpage correspond to the descriptions given below

# %%
#episode_containers[0].a['title']) # Title
#episode_containers[0].meta['content']) # Episode Number
#episode_containers[0].find('div', class_='airdate').text.strip() # Air Date
#episode_containers[0].find('span', class_='ipl-rating-star__rating').text # Episode Rating
#episode_containers[0].find('span', class_='ipl-rating-star__total-votes').text # Total No. Of Votes
#episode_containers[0].find('div', class_='item_description').text.strip() # Episode Description

# %% [markdown]
# # Defining Functions

# %%
def get_season_url(season):
    """Return the URL for a chosen season"""
    simpsons_url = 'https://www.imdb.com/title/tt0096697/episodes?season='
    season_url = simpsons_url + str(season)
    return season_url

# %%
def extract_season_data(season_url):
    """Extract the webpage data and pull out each individual episode into an 'episode container' which contains its
    row in the table."""
        
    # Request from the server the content of the web page by using get()
    response = get(season_url)

    # Parse the content of the request with BeautifulSoup
    page_html = BeautifulSoup(response.text, 'html.parser')

    # Select all the episode containers from the season's page
    episode_containers = page_html.find_all('div', class_='info')
    
    return episode_containers

# %%
def extract_ep_data_from_container(episode_container, season):
    """Extract the individual field data from the 'episode container' of a single episode."""
    
    # Get the info of each episode on the page
    try:
        episode_number = episode_container.meta['content']
    except:
        episode_number = ''

    try:
        title = episode_container.a['title']
    except:
        title = ''

    try:
        airdate = episode_container.find('div', class_='airdate').text.strip()
    except:
        airdate = ''

    try:
        rating = episode_container.find('span', class_='ipl-rating-star__rating').text
    except:
        rating = ''

    try:
        total_votes = episode_container.find('span', class_='ipl-rating-star__total-votes').text
        total_votes = total_votes.strip("()")
    except:
        total_votes = ''

    try:
        desc = episode_container.find('div', class_='item_description').text.strip()
    except:
        desc = ''
        
    # Compiling the episode info
    episode_data = [season, episode_number, title, airdate, rating, total_votes, desc]
    
    return episode_data

# %%
def convert_ep_array_to_dataframe(episodes):
    """Convert the array of episode data into a pandas dataframe"""
    episodes = pd.DataFrame(episodes, columns=['season', 'episode_no', 'title', 
                                               'airdate', 'rating', 'total_votes', 'desc'])
    return episodes

# %%
def gather_imdb_data():
    """Gather data from IMDb for episodes of the simpsons"""
    # Initializing the series that the loop will populate
    ep_array = []
    max_season = 31
    
    # For every season in the series-- range depends on the show
    for sn in range(1, max_season+1):
        season_url = get_season_url(sn)
        episode_containers = extract_season_data(season_url)

        # For each episode in each season
        for episode in episode_containers:
            episode_data = extract_ep_data_from_container(episode, sn)

            # Append the episode info to the complete dataset
            ep_array.append(episode_data)

    ep_dataframe = convert_ep_array_to_dataframe(ep_array)
    
    return ep_dataframe

# %% [markdown]
# # Gather Data

# %%
simpsons_episodes = gather_imdb_data()

# %%
simpsons_episodes.head()
# Out:
#    season episode_no                              title       airdate rating  \
# 0       1          1  Simpsons Roasting on an Open Fire   2 Sep. 1990    8.2
# 1       1          2                    Bart the Genius  14 Jan. 1990    7.7
# 2       1          3                    Homer's Odyssey  21 Jan. 1990    7.4
# 3       1          4      There's No Disgrace Like Home  28 Jan. 1990    7.7
# 4       1          5                   Bart the General   4 Feb. 1990    8.0
#
#   total_votes                                               desc
# 0       5,966  The family is forced to spend all of their sav...
# 1       3,834  Bart ends up at a school for gifted children a...
# 2       3,371  After losing his job, Homer contemplates endin...
# 3       3,301  After being embarrassed by the rest of the fam...
# 4       3,353  After being beaten up by Nelson Muntz one too ...

# %%
simpsons_episodes.to_pickle("./simpsons_episodes.pkl")

# %%
print('Data was extracted for {} episodes.'.format(simpsons_episodes.shape[0]))
# Out:
# Data was extracted for 683 episodes.

# %%
simpsons_episodes
# Out:
#      season episode_no                                              title  \
# 0         1          1                  Simpsons Roasting on an Open Fire
# 1         1          2                                    Bart the Genius
# 2         1          3                                    Homer's Odyssey
# 3         1          4                      There's No Disgrace Like Home
# 4         1          5                                   Bart the General
# 5         1          6                                       Moaning Lisa
# 6         1          7                           The Call of the Simpsons
# 7         1          8                                  The Telltale Head
# 8         1          9                              Life on the Fast Lane
# 9         1         10                                  Homer's Night Out
# 10        1         11                                The Crepes of Wrath
# 11        1         12                                 Krusty Gets Busted
# 12        1         13                             Some Enchanted Evening
# 13        2          1                                     Bart Gets an F
# 14        2          2                                Simpson and Delilah
# 15        2          3                                Treehouse of Horror
# 16        2          4  Two Cars in Every Garage and Three Eyes on Eve...
# 17        2          5                                      Dancin' Homer
# 18        2          6                               Dead Putting Society
# 19        2          7                              Bart vs. Thanksgiving
# 20        2          8                                 Bart the Daredevil
# 21        2          9                           Itchy & Scratchy & Marge
# 22        2         10                             Bart Gets Hit by a Car
# 23        2         11            One Fish, Two Fish, Blowfish, Blue Fish
# 24        2         12                                     The Way We Was
# 25        2         13             Homer vs. Lisa and the 8th Commandment
# 26        2         14                                 Principal Charming
# 27        2         15                        Oh Brother, Where Art Thou?
# 28        2         16                               Bart's Dog Gets an F
# 29        2         17                                          Old Money
# ..      ...        ...                                                ...
# 653      30         16                        I Want You (She's So Heavy)
# 654      30         17                                        E My Sports
# 655      30         18                          Bart vs. Itchy & Scratchy
# 656      30         19                                 Girl's in the Band
# 657      30         20                 I'm Just a Girl Who Can't Say D'oh
# 658      30         21                                        D'oh Canada
# 659      30         22                                    Woo-Hoo Dunnit?
# 660      30         23                     Crystal Blue-Haired Persuasion
# 661      31          1                The Winter of Our Monetized Content
# 662      31          2                                 Go Big or Go Homer
# 663      31          3                                  The Fat Blue Line
# 664      31          4                            Treehouse of Horror XXX
# 665      31          5                               Gorillas on the Mast
# 666      31          6                               Marge the Lumberjill
# 667      31          7                                 Livin la Pura Vida
# 668      31          8                             Thanksgiving of Horror
# 669      31          9             Todd, Todd, Why Hast Thou Forsaken Me?
# 670      31         10                           Bobby, It's Cold Outside
# 671      31         11                                  Hail to the Teeth
# 672      31         12                   The Miseducation of Lisa Simpson
# 673      31         13                                          Frinkcoin
# 674      31         14                                   Bart the Bad Guy
# 675      31         15                                         Screenless
# 676      31         16                                     Better Off Ned
# 677      31         17                                    Highway to Well
# 678      31         18           The Incredible Lightness of Being a Baby
# 679      31         19                                    Warrin' Priests
# 680      31         20                             Warrin' Priests Part 2
# 681      31         21                        The Hateful Eight-Year-Olds
# 682      31         22                                 The Way of the Dog
#
#           airdate rating total_votes  \
# 0     2 Sep. 1990    8.2       5,966
# 1    14 Jan. 1990    7.7       3,834
# 2    21 Jan. 1990    7.4       3,371
# 3    28 Jan. 1990    7.7       3,301
# 4     4 Feb. 1990    8.0       3,353
# 5    11 Feb. 1990    7.6       3,246
# 6     2 Sep. 1990    7.8       3,123
# 7    25 Feb. 1990    7.7       3,023
# 8    18 Mar. 1990    7.5       3,014
# 9    25 Mar. 1990    7.4       2,904
# 10   15 Apr. 1990    7.8       2,938
# 11   29 Apr. 1990    8.4       3,206
# 12    13 May 1990    7.7       2,939
# 13   11 Oct. 1990    8.3       3,214
# 14   18 Oct. 1990    8.2       3,039
# 15   19 Nov. 1991    8.3       3,423
# 16    1 Nov. 1990    8.1       2,783
# 17    8 Nov. 1990    7.4       2,685
# 18   15 Nov. 1990    8.0       2,620
# 19   22 Nov. 1990    7.8       2,582
# 20    6 Dec. 1990    8.4       2,829
# 21   20 Dec. 1990    8.1       2,660
# 22   10 Jan. 1991    7.8       2,542
# 23   24 Jan. 1991    8.8       3,131
# 24   31 Jan. 1991    8.3       2,645
# 25    7 Feb. 1991    8.0       2,499
# 26   14 Feb. 1991    7.5       2,416
# 27   21 Feb. 1991    8.3       2,655
# 28    7 Mar. 1991    7.5       2,393
# 29   28 Mar. 1991    7.6       2,360
# ..            ...    ...         ...
# 653   10 May 2019    5.7         494
# 654   17 May 2019    6.3         538
# 655  24 Mar. 2019    4.5       1,059
# 656  31 Mar. 2019    6.3         525
# 657   7 Apr. 2019    5.3         522
# 658  28 Apr. 2019    5.3         639
# 659    5 May 2019    6.0         521
# 660   12 May 2019    5.9         495
# 661  17 Jan. 2020    5.7         711
# 662  24 Jan. 2020    5.9         621
# 663  31 Jan. 2020    6.5         537
# 664   7 Feb. 2020    6.9         691
# 665  14 Feb. 2020    6.2         494
# 666  21 Feb. 2020    5.4         574
# 667  24 Dec. 2019    6.3         536
# 668  28 Feb. 2020    7.3         674
# 669   6 Mar. 2020    6.5         597
# 670  13 Mar. 2020    6.6         466
# 671  20 Mar. 2020    6.1         419
# 672  27 Mar. 2020    6.6         422
# 673   3 Apr. 2020    5.9         389
# 674  10 Apr. 2020    7.3         514
# 675  17 Apr. 2020    6.5         390
# 676  24 Apr. 2020    6.5         373
# 677  28 Apr. 2020    7.0         431
# 678    1 May 2020    6.3         360
# 679    8 May 2020    6.0         446
# 680   15 May 2020    5.8         412
# 681   22 May 2020    6.7         394
# 682   29 May 2020    7.4         442
#
#                                                   desc
# 0    The family is forced to spend all of their sav...
# 1    Bart ends up at a school for gifted children a...
# 2    After losing his job, Homer contemplates endin...
# 3    After being embarrassed by the rest of the fam...
# 4    After being beaten up by Nelson Muntz one too ...
# 5    A depressed Lisa's spirit is lifted when she m...
# 6    Homer takes the family camping, but it soon be...
# 7    Bart gets more than he bargained for when he s...
# 8    Marge contemplates an affair with a handsome b...
# 9    After a photograph of Homer canoodling with an...
# 10   Bart is sent to France on a student exchange p...
# 11   Homer witnesses a robbery at the Kwik-E-Mart, ...
# 12   Homer and Marge enjoy a night on the town, lea...
# 13   Mrs. Krabappel, fed up with Bart's lackadaisic...
# 14   Homer lies on a medical insurance form in orde...
# 15   The Simpsons move into a cursed house, then ar...
# 16   After the power plant experiences bad publicit...
# 17   Homer's heckling of the Springfield Isotopes b...
# 18   In an attempt to show up Ned Flanders, Homer p...
# 19   On Thanksgiving, Bart runs away after fighting...
# 20   After seeing a motorcycle daredevil at a monst...
# 21   Marge becomes a crusader against cartoon viole...
# 22   While skateboarding down the street, Bart is h...
# 23   After apparently consuming poison blowfish, Ho...
# 24   Homer and Marge tell the story of how they met...
# 25   Homer gets a crooked cable guy to install free...
# 26   Homer tries to set Selma up with Principal Ski...
# 27   After Grampa is hospitalized, he reveals that ...
# 28   After an uncontrollable Santa's Little Helper ...
# 29   After Grampa's new girlfriend dies and leaves ...
# ..                                                 ...
# 653  When a romantic night ends in injury for Homer...
# 654  Homer discovers a passion for coaching Bart in...
# 655  Bart's friends start a boys rights activist gr...
# 656  Homer works extra shifts at the plant so Lisa ...
# 657  Marge becomes Director of Springfield's local ...
# 658  Lisa is mistakenly given political asylum in C...
# 659  The documentary crime series "Dateline: Spring...
# 660  Marge starts a business selling healing crysta...
# 661  Bart and Homer become social media celebrities...
# 662  Homer inspires a 35-year-old millennial who id...
# 663  When the wrong man is arrested for pickpocketi...
# 664  The 30th Treehouse of Horror features a demon ...
# 665  After visiting Aquatraz Water Park, Lisa and B...
# 666  Marge becomes a competitive lumberjack and goe...
# 667  The Simpsons join other Springfield families o...
# 668  The Simpsons face various Thanksgiving nightma...
# 669  Todd blames God for his mother's death and rej...
# 670  Sideshow Bob gets the role of Santa Claus at S...
# 671  Homer and Marge attend Artie Ziff's wedding an...
# 672  The sea captain finds treasure for which he's ...
# 673  Professor Frink invents a cryptocurrency that ...
# 674  Bart uses spoilers for a superhero movie he sa...
# 675  Marge implements a limit on screen time for th...
# 676  Jealous of Bart's bond with Ned, Homer mentors...
# 677  Marge gets a job at an upscale cannabis dispen...
# 678  Maggie reunites with baby Hudson, but Marge is...
# 679  Reverend Lovejoy investigates the mysterious p...
# 680  In Michigan, Reverend Lovejoy learns the true ...
# 681  Lisa joins a group of rich girls when she make...
# 682  The Simpsons explore the tragic past of Santa'...
#
# [683 rows x 7 columns]
